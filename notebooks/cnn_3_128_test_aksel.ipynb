# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nndl_model import *
import wandb

configure_logging()

# %%
# 1) Load data (uses DATA_DIR from your constants)
train_loader, val_loader, test_loader, M = make_dataloaders()

# %%
model = CNN_3_128_Test_Aksel(M=M)
# Out:
# Hyperparams: {'lr': 0.001, 'alpha': 1, 'beta': 1, 'gamma': 0.1}
# 2025-11-07 18:26:46,397 | INFO | CNN_3_128_Test_Aksel_v000 | Loaded model weights and state from /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000.

# %%
print(model.summary())
# Out:
# Model: name='CNN_3_128_Test_Aksel_v000'
# CNN_3_128_Test_Aksel(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): AdaptiveAvgPool2d(output_size=1)
#     (5): Flatten(start_dim=1, end_dim=-1)
#   )
#   (criterion): CrossEntropyLoss()
#   (head_super): Linear(in_features=64, out_features=4, bias=True)
#   (head_sub): Linear(in_features=64, out_features=88, bias=True)
# )
#
# {'best_acc_sub': 0.41971383147853736, 'best_acc_sup': 0.9459459459459459, 'best_loss': 2.142575404223274, 'epochs_trained': 34}

# %%
run = start_wandb_run(model)
# Out:
# wandb: Currently logged in as: akseldkw (akseldkw07) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/Users/Akseldkw/coding/Columbia/COMS4776-Data/wandb/wandb/run-20251107_182648-j25qjizc</code>
# Syncing run <strong><a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/j25qjizc' target="_blank">v000__20251107-182646</a></strong> to <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel</a>
#  View run at <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/j25qjizc' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/j25qjizc</a>

# %%
model.train_model(train_loader, val_loader, epochs=5)
# Out:
#  20%|██        | 1/5 [01:01<04:06, 61.63s/it]
# Epoch 50/54  |  Train Loss: 1.8441  |  Train Acc (sup/sub): 0.9295/0.5056  |  Val Loss: 1.9254  |  Val Acc (sup/sub): 0.9396/0.4944
#  40%|████      | 2/5 [02:02<03:04, 61.41s/it]
# Epoch 51/54  |  Train Loss: 1.8183  |  Train Acc (sup/sub): 0.9302/0.5174  |  Val Loss: 1.9536  |  Val Acc (sup/sub): 0.9348/0.4944
#  60%|██████    | 3/5 [03:04<02:02, 61.37s/it]
# New best model found at epoch 51!. Old (val) loss: 1.9089, New (val) loss: 1.8305
# Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# Epoch 52/54  |  Train Loss: 1.8112  |  Train Acc (sup/sub): 0.9300/0.5079  |  Val Loss: 1.8305  |  Val Acc (sup/sub): 0.9475/0.5135
#  80%|████████  | 4/5 [04:06<01:01, 61.54s/it]
# Epoch 53/54  |  Train Loss: 1.8042  |  Train Acc (sup/sub): 0.9306/0.5222  |  Val Loss: 1.8787  |  Val Acc (sup/sub): 0.9459/0.5008
# 100%|██████████| 5/5 [05:08<00:00, 61.68s/it]
# Epoch 54/54  |  Train Loss: 1.7708  |  Train Acc (sup/sub): 0.9397/0.5317  |  Val Loss: 1.8711  |  Val Acc (sup/sub): 0.9396/0.5183

# %%
print(model.summary())
# Out:
# Model: name='CNN_3_128_Test_Aksel_v000'
# CNN_3_128_Test_Aksel(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): AdaptiveAvgPool2d(output_size=1)
#     (5): Flatten(start_dim=1, end_dim=-1)
#   )
#   (criterion): CrossEntropyLoss()
#   (head_super): Linear(in_features=64, out_features=4, bias=True)
#   (head_sub): Linear(in_features=64, out_features=88, bias=True)
# )
#
# {'best_acc_sub': 0.5135135135135135, 'best_acc_sup': 0.9475357710651828, 'best_loss': 1.83054162417383, 'epochs_trained': 54}

# %%
# model.save_weights()

# %%
# raise ValueError("STOP")  # Remove this line to continue training

# %%
run.finish()
