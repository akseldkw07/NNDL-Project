# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nndl_model import *
import wandb

configure_logging()

# %%
# 1) Load data (uses DATA_DIR from your constants)
train_loader, val_loader, test_loader, M = make_dataloaders()

# %%
model = CNN_3_128_Test_Aksel(M=M)
# Out:
# [2025-11-07 20:45:46,542 | INFO | CNN_3_128_Test_Aksel_v000 ] Loaded model weights and state from /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000.
# [2025-11-07 20:45:46,543 | INFO | CNN_3_128_Test_Aksel_v000 ] Full State:
# {'hparams': {'alpha': 1,
#              'beta': 1,
#              'gamma': 0.1,
#              'improvement_tol': 0.0001,
#              'lr': 0.001,
#              'patience': 15},
#  'state': {'best_acc_sub': 0.5135,
#            'best_acc_sup': 0.9475,
#            'best_loss': 1.831,
#            'epochs_trained': 51}}

# %%
run = start_wandb_run(model)
# Out:
# wandb: Currently logged in as: akseldkw (akseldkw07) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/Users/Akseldkw/coding/Columbia/COMS4776-Data/wandb/wandb/run-20251107_204548-0rkf91gq</code>
# Syncing run <strong><a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/0rkf91gq' target="_blank">CNN_3_128_Test_Aksel_v000__20251107-204546</a></strong> to <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition' target="_blank">https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition</a>
#  View run at <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/0rkf91gq' target="_blank">https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/0rkf91gq</a>

# %%
model.train_model(train_loader, val_loader, epochs=5)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# [2025-11-07 20:47:25,701 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 20:47:25,710 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) — early-stop counter reset to 0.
# [2025-11-07 20:47:25,710 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 52/56  |  Train Loss: 1.7766  |  Train Acc (sup/sub): 0.9367/0.5257  |  Val Loss: 1.8142  |  Val Acc (sup/sub): 0.9475/0.5056
#  20%|██        | 1/5 [01:01<04:07, 61.88s/it]
# [2025-11-07 20:48:27,482 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 20:48:27,494 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (acc_sub) — early-stop counter reset to 0.
# [2025-11-07 20:48:27,494 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 53/56  |  Train Loss: 1.7648  |  Train Acc (sup/sub): 0.9330/0.5312  |  Val Loss: 1.8434  |  Val Acc (sup/sub): 0.9444/0.5151
#  40%|████      | 2/5 [02:03<03:05, 61.82s/it]
# [2025-11-07 20:49:29,611 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 20:49:29,618 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) — early-stop counter reset to 0.
# [2025-11-07 20:49:29,619 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 54/56  |  Train Loss: 1.7622  |  Train Acc (sup/sub): 0.9353/0.5292  |  Val Loss: 1.7968  |  Val Acc (sup/sub): 0.9396/0.5135
#  60%|██████    | 3/5 [03:05<02:03, 61.96s/it]
# [2025-11-07 20:50:30,905 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 20:50:30,915 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved () — early-stop counter reset to 0.
# [2025-11-07 20:50:30,916 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 55/56  |  Train Loss: 1.7544  |  Train Acc (sup/sub): 0.9376/0.5367  |  Val Loss: 1.8150  |  Val Acc (sup/sub): 0.9396/0.5119
#  80%|████████  | 4/5 [04:07<01:01, 61.70s/it]
# [2025-11-07 20:51:32,914 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 20:51:32,925 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (acc_sup) — early-stop counter reset to 0.
# [2025-11-07 20:51:32,926 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 56/56  |  Train Loss: 1.7566  |  Train Acc (sup/sub): 0.9341/0.5296  |  Val Loss: 1.8084  |  Val Acc (sup/sub): 0.9507/0.5135
# 100%|██████████| 5/5 [05:09<00:00, 61.82s/it]

# %%
model.summary()
# Out:
# Model: name='CNN_3_128_Test_Aksel_v000'
#
# CNN_3_128_Test_Aksel(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): AdaptiveAvgPool2d(output_size=1)
#     (5): Flatten(start_dim=1, end_dim=-1)
#   )
#   (criterion): CrossEntropyLoss()
#   (head_super): Linear(in_features=64, out_features=4, bias=True)
#   (head_sub): Linear(in_features=64, out_features=88, bias=True)
# )
#
# {'hparams': {'alpha': 1,
#              'beta': 1,
#              'gamma': 0.1,
#              'improvement_tol': 0.0001,
#              'lr': 0.001,
#              'patience': 10},
#  'state': {'best_acc_sub': 0.5135135135135135,
#            'best_acc_sup': 0.9475357710651828,
#            'best_loss': 1.83054162417383,
#            'epochs_trained': 51}}

# %%
model.save_weights()
# Out:
# [2025-11-07 20:36:39,702 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt

# %%
# raise ValueError("STOP")  # Remove this line to continue training

# %%
run.finish()
