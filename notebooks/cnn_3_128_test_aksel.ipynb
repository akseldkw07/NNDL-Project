# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nndl_model import *
import wandb

# %%
# 1) Load data (uses DATA_DIR from your constants)
train_loader, val_loader, test_loader, M = make_dataloaders()

# %%
model = CNN_3_128_Test_Aksel(M=M)
# Out:
# Hyperparams: {'lr': 0.001, 'alpha': 1, 'beta': 1, 'gamma': 0.1}

# %%
print(model.summary())
# Out:
# Model: name='CNN_3_128_Test_Aksel_v000'
# CNN_3_128_Test_Aksel(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): AdaptiveAvgPool2d(output_size=1)
#     (5): Flatten(start_dim=1, end_dim=-1)
#   )
#   (criterion): CrossEntropyLoss()
#   (head_super): Linear(in_features=64, out_features=4, bias=True)
#   (head_sub): Linear(in_features=64, out_features=88, bias=True)
# )
#
# {'best_acc_sub': 0.3751987281399046, 'best_acc_sup': 0.9395866454689984, 'best_loss': 2.3442037613479054, 'epochs_trained': 26}

# %%
run = start_wandb_run(model)
# Out:
# wandb: Currently logged in as: akseldkw (akseldkw07) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/Users/Akseldkw/coding/Columbia/COMS4776-Data/wandb/wandb/run-20251107_175802-rfv63q24</code>
# Syncing run <strong><a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/rfv63q24' target="_blank">v000__20251107-175800</a></strong> to <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel</a>
#  View run at <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/rfv63q24' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/rfv63q24</a>

# %%
model.train_model(train_loader, val_loader, epochs=5)
# Out:
#  20%|██        | 1/5 [01:01<04:06, 61.71s/it]
# Epoch 28/33 | Train Loss: 2.2849 | Train Acc (sup/sub): 0.9198/0.4027 | Val Loss: 2.3604 | Val Acc (sup/sub): 0.9412/0.3688
#  40%|████      | 2/5 [02:03<03:05, 61.98s/it]
# Epoch 29/34 | Train Loss: 2.2974 | Train Acc (sup/sub): 0.9196/0.4078 | Val Loss: 2.4161 | Val Acc (sup/sub): 0.9316/0.3609
#  60%|██████    | 3/5 [03:05<02:03, 61.99s/it]
# Epoch 30/35 | Train Loss: 2.2304 | Train Acc (sup/sub): 0.9212/0.4207 | Val Loss: 2.3821 | Val Acc (sup/sub): 0.9205/0.3911
#  80%|████████  | 4/5 [04:08<01:02, 62.13s/it]
# New best model found at epoch 30!. Old (val) loss: 2.3442, New (val) loss: 2.2814
# Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# Epoch 31/36 | Train Loss: 2.2373 | Train Acc (sup/sub): 0.9203/0.4114 | Val Loss: 2.2814 | Val Acc (sup/sub): 0.9459/0.3943
# 100%|██████████| 5/5 [05:10<00:00, 62.02s/it]
# New best model found at epoch 31!. Old (val) loss: 2.2814, New (val) loss: 2.1910
# Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# Epoch 32/37 | Train Loss: 2.2004 | Train Acc (sup/sub): 0.9267/0.4174 | Val Loss: 2.1910 | Val Acc (sup/sub): 0.9491/0.4340

# %%
model.best_val_loss
# Out:
# {'best_acc_sub': 0.3751987281399046,
#  'best_acc_sup': 0.9395866454689984,
#  'best_loss': 2.3442037613479054,
#  'epochs_trained': 27}

# %%
# model.save_weights()

# %%
raise ValueError("STOP")  # Remove this line to continue training

# %%
run.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>Train Accuracy (sub)</td><td>▁▂▂▃▃▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>Train Accuracy (super)</td><td>▁▄▅▆▆▇▇▇██████████████████</td></tr><tr><td>Train Loss</td><td>█▇▆▅▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>Validation Accuracy (sub)</td><td>▁▁▂▃▃▄▄▅▅▅▆▅▅▆▆▆▆▇▇▇▇▇█▇██</td></tr><tr><td>Validation Accuracy (super)</td><td>▁▃▄▆▆▇▇▇▆▇▇▇▇▇█▇██████████</td></tr><tr><td>Validation Loss</td><td>█▇▆▅▅▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>26</td></tr><tr><td>Train Accuracy (sub)</td><td>0.3847</td></tr><tr><td>Train Accuracy (super)</td><td>0.92207</td></tr><tr><td>Train Loss</td><td>2.33416</td></tr><tr><td>Validation Accuracy (sub)</td><td>0.3752</td></tr><tr><td>Validation Accuracy (super)</td><td>0.93959</td></tr><tr><td>Validation Loss</td><td>2.3442</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">v000__20251107-163715</strong> at: <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/tpdvzfgq' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/tpdvzfgq</a><br> View project at: <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/Users/Akseldkw/coding/Columbia/COMS4776-Data/wandb/wandb/run-20251107_163717-tpdvzfgq/logs</code>
