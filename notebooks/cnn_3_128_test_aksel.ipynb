# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nndl_model import *
import wandb

# %%
# 1) Load data (uses DATA_DIR from your constants)
train_loader, val_loader, test_loader, M = make_dataloaders()

# %%
model = CNN_3_128_Test_Aksel(M=M)
# Out:
# Hyperparams: {'lr': 0.001, 'alpha': 1, 'beta': 1, 'gamma': 0.1}

# %%
run = start_wandb_run(model)
# Out:
# wandb: Currently logged in as: akseldkw (akseldkw07) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/Users/Akseldkw/coding/Columbia/COMS4776-Data/wandb/wandb/run-20251107_163717-tpdvzfgq</code>
# Syncing run <strong><a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/tpdvzfgq' target="_blank">v000__20251107-163715</a></strong> to <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel</a>
#  View run at <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/tpdvzfgq' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/tpdvzfgq</a>

# %%
model.train_model(train_loader, val_loader, epochs=5)
# Out:
# 100%|██████████| 1/1 [01:03<00:00, 63.33s/it]
# New best model found at epoch 1!. Old loss: inf, New loss: 5.0930
# Epoch 1/1 Train Loss: 5.4059 Train Acc (sup/sub): 0.5031/0.0223
# Val Loss: 5.0930 Val Acc (sup/sub): 0.6566/0.0493

# %%
model.best_loss
# Out:
# 5.0930392488197604

# %%
model.save_weights()

# %%
run.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁</td></tr><tr><td>Train Accuracy (sub)</td><td>▁</td></tr><tr><td>Train Accuracy (super)</td><td>▁</td></tr><tr><td>Validation Accuracy (sub)</td><td>▁</td></tr><tr><td>Validation Accuracy (super)</td><td>▁</td></tr><tr><td>+2</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>1</td></tr><tr><td>Train Accuracy (sub)</td><td>0.00018</td></tr><tr><td>Train Accuracy (super)</td><td>0.00618</td></tr><tr><td>Train Loss</td><td>nan</td></tr><tr><td>Validation Accuracy (sub)</td><td>0</td></tr><tr><td>Validation Accuracy (super)</td><td>0</td></tr><tr><td>Validation Loss</td><td>nan</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">v000__20251107-160832</strong> at: <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/nsb138s6' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel/runs/nsb138s6</a><br> View project at: <a href='https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel' target="_blank">https://wandb.ai/nndl-project-F25/CNN_3_128_Test_Aksel</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/Users/Akseldkw/coding/Columbia/COMS4776-Data/wandb/wandb/run-20251107_160832-nsb138s6/logs</code>
