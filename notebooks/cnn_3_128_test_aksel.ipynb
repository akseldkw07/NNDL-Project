# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nndl_model import *
import wandb

configure_logging()

# %%
# 1) Load data (uses DATA_DIR from your constants)
train_loader, val_loader, test_loader, M = make_dataloaders()

# %%
model = CNN_3_128_Test_Aksel(M=M)
# Out:
# [2025-11-07 21:32:48,354 | INFO | CNN_3_128_Test_Aksel_v000 ] Loaded model weights and state from /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000.
# [2025-11-07 21:32:48,354 | INFO | CNN_3_128_Test_Aksel_v000 ] Full State:
# {'hparams': {'alpha': 1,
#              'beta': 1,
#              'gamma': 0.1,
#              'improvement_tol': 0.0001,
#              'lr': 0.001,
#              'patience': 25},
#  'state': {'best_acc_sub': 0.5501,
#            'best_acc_sup': 0.9507,
#            'best_loss': 1.731,
#            'epochs_trained': 62}}

# %%
run = start_wandb_run(model)
# Out:
# wandb: Currently logged in as: akseldkw (akseldkw07) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/Users/Akseldkw/coding/Columbia/COMS4776-Data/wandb/wandb/run-20251107_213249-j5kmnkjr</code>
# Syncing run <strong><a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/j5kmnkjr' target="_blank">CNN_3_128_Test_Aksel_v000__20251107-213248</a></strong> to <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition' target="_blank">https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition</a>
#  View run at <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/j5kmnkjr' target="_blank">https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/j5kmnkjr</a>

# %%
# model.train_model(train_loader, val_loader, epochs=1)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# [2025-11-07 21:33:52,855 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:33:52,865 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) - early-stop counter reset to 0.
# [2025-11-07 21:33:52,865 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 63/562  |  Train Loss: 1.6405  |  Train Acc (sup/sub): 0.9396/0.5584  |  Val Loss: 1.7100  |  Val Acc (sup/sub): 0.9475/0.5437
#   0%|          | 1/500 [01:01<8:31:58, 61.56s/it]
# [2025-11-07 21:34:53,710 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:34:53,722 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss, acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:34:53,722 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 64/562  |  Train Loss: 1.5939  |  Train Acc (sup/sub): 0.9422/0.5692  |  Val Loss: 1.6726  |  Val Acc (sup/sub): 0.9507/0.5517
#   0%|          | 2/500 [02:02<8:27:30, 61.15s/it]
# [2025-11-07 21:35:54,845 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 65/562  |  Train Loss: 1.5967  |  Train Acc (sup/sub): 0.9397/0.5688  |  Val Loss: 1.6783  |  Val Acc (sup/sub): 0.9459/0.5485
#   1%|          | 3/500 [03:03<8:26:24, 61.14s/it]
# [2025-11-07 21:36:55,966 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 66/562  |  Train Loss: 1.6080  |  Train Acc (sup/sub): 0.9371/0.5665  |  Val Loss: 1.6808  |  Val Acc (sup/sub): 0.9428/0.5517
#   1%|          | 4/500 [04:04<8:25:20, 61.13s/it]
# [2025-11-07 21:37:56,807 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:37:56,819 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:37:56,820 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 67/562  |  Train Loss: 1.5730  |  Train Acc (sup/sub): 0.9351/0.5837  |  Val Loss: 1.6835  |  Val Acc (sup/sub): 0.9444/0.5548
#   1%|          | 5/500 [05:05<8:23:29, 61.03s/it]
# [2025-11-07 21:38:58,625 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:38:58,632 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss, acc_sub, acc_sup) - early-stop counter reset to 0.
# [2025-11-07 21:38:58,633 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 68/562  |  Train Loss: 1.5677  |  Train Acc (sup/sub): 0.9399/0.5826  |  Val Loss: 1.6200  |  Val Acc (sup/sub): 0.9523/0.5707
#   1%|          | 6/500 [06:07<8:24:40, 61.30s/it]
# [2025-11-07 21:40:00,235 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:40:00,246 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss, acc_sub, acc_sup) - early-stop counter reset to 0.
# [2025-11-07 21:40:00,247 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 69/562  |  Train Loss: 1.5465  |  Train Acc (sup/sub): 0.9420/0.5870  |  Val Loss: 1.5889  |  Val Acc (sup/sub): 0.9555/0.5803
#   1%|▏         | 7/500 [07:08<8:24:30, 61.40s/it]
# [2025-11-07 21:41:01,290 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:41:01,303 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) - early-stop counter reset to 0.
# [2025-11-07 21:41:01,303 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 70/562  |  Train Loss: 1.5478  |  Train Acc (sup/sub): 0.9420/0.5851  |  Val Loss: 1.5760  |  Val Acc (sup/sub): 0.9539/0.5803
#   2%|▏         | 8/500 [08:09<8:22:35, 61.29s/it]
# [2025-11-07 21:42:02,567 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 71/562  |  Train Loss: 1.5412  |  Train Acc (sup/sub): 0.9412/0.5863  |  Val Loss: 1.6398  |  Val Acc (sup/sub): 0.9539/0.5469
#   2%|▏         | 9/500 [09:11<8:21:29, 61.28s/it]
# [2025-11-07 21:43:03,870 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:43:03,882 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:43:03,883 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 72/562  |  Train Loss: 1.5337  |  Train Acc (sup/sub): 0.9426/0.5929  |  Val Loss: 1.6091  |  Val Acc (sup/sub): 0.9459/0.5882
#   2%|▏         | 10/500 [10:12<8:20:33, 61.29s/it]
# [2025-11-07 21:44:04,973 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:44:04,984 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss, acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:44:04,984 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 73/562  |  Train Loss: 1.5541  |  Train Acc (sup/sub): 0.9360/0.5824  |  Val Loss: 1.5531  |  Val Acc (sup/sub): 0.9539/0.5914
#   2%|▏         | 11/500 [11:13<8:19:03, 61.23s/it]
# [2025-11-07 21:45:05,916 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:45:05,924 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss, acc_sup) - early-stop counter reset to 0.
# [2025-11-07 21:45:05,924 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 74/562  |  Train Loss: 1.5208  |  Train Acc (sup/sub): 0.9449/0.5890  |  Val Loss: 1.5331  |  Val Acc (sup/sub): 0.9571/0.5692
#   2%|▏         | 12/500 [12:14<8:17:18, 61.14s/it]
# [2025-11-07 21:46:07,369 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 75/562  |  Train Loss: 1.5445  |  Train Acc (sup/sub): 0.9412/0.6008  |  Val Loss: 1.6028  |  Val Acc (sup/sub): 0.9491/0.5771
#   3%|▎         | 13/500 [13:16<8:17:01, 61.24s/it]
# [2025-11-07 21:47:08,700 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:47:08,709 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:47:08,710 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 76/562  |  Train Loss: 1.5199  |  Train Acc (sup/sub): 0.9399/0.5911  |  Val Loss: 1.5539  |  Val Acc (sup/sub): 0.9507/0.5962
#   3%|▎         | 14/500 [14:17<8:16:15, 61.27s/it]
# [2025-11-07 21:48:10,246 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 77/562  |  Train Loss: 1.4911  |  Train Acc (sup/sub): 0.9387/0.6045  |  Val Loss: 1.5914  |  Val Acc (sup/sub): 0.9380/0.5787
#   3%|▎         | 15/500 [15:18<8:15:54, 61.35s/it]
# [2025-11-07 21:49:11,534 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 78/562  |  Train Loss: 1.4972  |  Train Acc (sup/sub): 0.9403/0.6010  |  Val Loss: 1.5561  |  Val Acc (sup/sub): 0.9571/0.5755
#   3%|▎         | 16/500 [16:20<8:14:43, 61.33s/it]
# [2025-11-07 21:50:12,865 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:50:12,877 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) - early-stop counter reset to 0.
# [2025-11-07 21:50:12,878 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 79/562  |  Train Loss: 1.4815  |  Train Acc (sup/sub): 0.9404/0.5976  |  Val Loss: 1.5281  |  Val Acc (sup/sub): 0.9571/0.5914
#   3%|▎         | 17/500 [17:21<8:13:44, 61.33s/it]
# [2025-11-07 21:51:14,435 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 80/562  |  Train Loss: 1.4555  |  Train Acc (sup/sub): 0.9445/0.6093  |  Val Loss: 1.5798  |  Val Acc (sup/sub): 0.9507/0.5819
#   4%|▎         | 18/500 [18:23<8:13:15, 61.40s/it]
# [2025-11-07 21:52:15,786 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:52:15,797 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) - early-stop counter reset to 0.
# [2025-11-07 21:52:15,798 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 81/562  |  Train Loss: 1.4537  |  Train Acc (sup/sub): 0.9440/0.6141  |  Val Loss: 1.5251  |  Val Acc (sup/sub): 0.9523/0.5914
#   4%|▍         | 19/500 [19:24<8:12:08, 61.39s/it]
# [2025-11-07 21:53:17,111 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:53:17,120 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss, acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:53:17,121 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 82/562  |  Train Loss: 1.4456  |  Train Acc (sup/sub): 0.9433/0.6114  |  Val Loss: 1.5093  |  Val Acc (sup/sub): 0.9539/0.5994
#   4%|▍         | 20/500 [20:25<8:10:57, 61.37s/it]
# [2025-11-07 21:54:18,009 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:54:18,019 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss, acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:54:18,019 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 83/562  |  Train Loss: 1.4344  |  Train Acc (sup/sub): 0.9436/0.6109  |  Val Loss: 1.4603  |  Val Acc (sup/sub): 0.9507/0.6089
#   4%|▍         | 21/500 [21:26<8:08:48, 61.23s/it]
# [2025-11-07 21:55:18,358 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:55:18,370 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:55:18,371 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 84/562  |  Train Loss: 1.4286  |  Train Acc (sup/sub): 0.9445/0.6204  |  Val Loss: 1.4679  |  Val Acc (sup/sub): 0.9555/0.6153
#   4%|▍         | 22/500 [22:27<8:05:41, 60.97s/it]
# [2025-11-07 21:56:18,954 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:56:18,966 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:56:18,967 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 85/562  |  Train Loss: 1.4276  |  Train Acc (sup/sub): 0.9440/0.6185  |  Val Loss: 1.4909  |  Val Acc (sup/sub): 0.9507/0.6169
#   5%|▍         | 23/500 [23:27<8:03:47, 60.85s/it]
# [2025-11-07 21:57:19,668 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 86/562  |  Train Loss: 1.4111  |  Train Acc (sup/sub): 0.9449/0.6206  |  Val Loss: 1.4725  |  Val Acc (sup/sub): 0.9475/0.6121
#   5%|▍         | 24/500 [24:28<8:02:25, 60.81s/it]
# [2025-11-07 21:58:20,359 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:58:20,371 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (acc_sub) - early-stop counter reset to 0.
# [2025-11-07 21:58:20,372 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 87/562  |  Train Loss: 1.4110  |  Train Acc (sup/sub): 0.9445/0.6181  |  Val Loss: 1.4745  |  Val Acc (sup/sub): 0.9475/0.6232
#   5%|▌         | 25/500 [25:29<8:01:08, 60.78s/it]
# [2025-11-07 21:59:21,166 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 88/562  |  Train Loss: 1.4034  |  Train Acc (sup/sub): 0.9463/0.6264  |  Val Loss: 1.4927  |  Val Acc (sup/sub): 0.9539/0.5851
#   5%|▌         | 26/500 [26:29<8:00:10, 60.78s/it]
# [2025-11-07 22:00:21,826 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 89/562  |  Train Loss: 1.3955  |  Train Acc (sup/sub): 0.9435/0.6254  |  Val Loss: 1.4932  |  Val Acc (sup/sub): 0.9539/0.6137
#   5%|▌         | 27/500 [27:30<7:58:52, 60.75s/it]
# [2025-11-07 22:01:22,693 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch
| INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 101/562  |  Train Loss: 1.3192  |  Train Acc (sup/sub): 0.9452/0.6483  |  Val Loss: 1.4470  |  Val Acc (sup/sub): 0.9523/0.6041
#   8%|▊         | 39/500 [39:36<7:46:14, 60.68s/it]
# [2025-11-07 22:13:28,995 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 22:13:29,008 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss, acc_sub) - early-stop counter reset to 0.
# [2025-11-07 22:13:29,008 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 102/562  |  Train Loss: 1.2991  |  Train Acc (sup/sub): 0.9470/0.6443  |  Val Loss: 1.3484  |  Val Acc (sup/sub): 0.9555/0.6423
#   8%|▊         | 40/500 [40:37<7:46:00, 60.78s/it]
# [2025-11-07 22:14:29,617 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 103/562  |  Train Loss: 1.2904  |  Train Acc (sup/sub): 0.9452/0.6558  |  Val Loss: 1.4135  |  Val Acc (sup/sub): 0.9571/0.6216
#   8%|▊         | 41/500 [41:38<7:44:36, 60.73s/it]
# [2025-11-07 22:15:30,447 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 104/562  |  Train Loss: 1.3044  |  Train Acc (sup/sub): 0.9458/0.6514  |  Val Loss: 1.4229  |  Val Acc (sup/sub): 0.9571/0.6264
#   8%|▊         | 42/500 [42:39<7:43:48, 60.76s/it]
# [2025-11-07 22:16:30,863 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 105/562  |  Train Loss: 1.2870  |  Train Acc (sup/sub): 0.9484/0.6584  |  Val Loss: 1.3668  |  Val Acc (sup/sub): 0.9587/0.6359
#   9%|▊         | 43/500 [43:39<7:42:00, 60.66s/it]
# [2025-11-07 22:17:31,640 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 106/562  |  Train Loss: 1.2926  |  Train Acc (sup/sub): 0.9480/0.6519  |  Val Loss: 1.4424  |  Val Acc (sup/sub): 0.9491/0.6169
#   9%|▉         | 44/500 [44:40<7:41:15, 60.69s/it]
# [2025-11-07 22:18:32,502 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 107/562  |  Train Loss: 1.2841  |  Train Acc (sup/sub): 0.9456/0.6540  |  Val Loss: 1.3837  |  Val Acc (sup/sub): 0.9571/0.6391
#   9%|▉         | 45/500 [45:41<7:40:38, 60.74s/it]
# [2025-11-07 22:19:33,324 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 108/562  |  Train Loss: 1.2772  |  Train Acc (sup/sub): 0.9493/0.6586  |  Val Loss: 1.4043  |  Val Acc (sup/sub): 0.9555/0.6375
#   9%|▉         | 46/500 [46:42<7:39:48, 60.77s/it]
# [2025-11-07 22:20:34,419 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 22:20:34,430 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss, acc_sup) - early-stop counter reset to 0.
# [2025-11-07 22:20:34,431 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 109/562  |  Train Loss: 1.2772  |  Train Acc (sup/sub): 0.9489/0.6579  |  Val Loss: 1.3375  |  Val Acc (sup/sub): 0.9618/0.6391
#   9%|▉         | 47/500 [47:43<7:39:33, 60.87s/it]
# [2025-11-07 22:21:35,090 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 110/562  |  Train Loss: 1.2530  |  Train Acc (sup/sub): 0.9512/0.6635  |  Val Loss: 1.3392  |  Val Acc (sup/sub): 0.9587/0.6343
#  10%|▉         | 48/500 [48:43<7:38:04, 60.81s/it]
# [2025-11-07 22:22:35,185 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 22:22:35,197 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) - early-stop counter reset to 0.
# [2025-11-07 22:22:35,198 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 111/562  |  Train Loss: 1.2517  |  Train Acc (sup/sub): 0.9528/0.6635  |  Val Loss: 1.3048  |  Val Acc (sup/sub): 0.9603/0.6407
#  10%|▉         | 49/500 [49:43<7:35:28, 60.60s/it]
# [2025-11-07 22:23:35,469 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch
| INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 144/562  |  Train Loss: 1.1056  |  Train Acc (sup/sub): 0.9548/0.7005  |  Val Loss: 1.2475  |  Val Acc (sup/sub): 0.9555/0.6677
#  16%|█▋        | 82/500 [1:23:22<7:07:30, 61.36s/it]
# [2025-11-07 22:57:15,130 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 145/562  |  Train Loss: 1.0881  |  Train Acc (sup/sub): 0.9562/0.7052  |  Val Loss: 1.2306  |  Val Acc (sup/sub): 0.9634/0.6566
#  17%|█▋        | 83/500 [1:24:23<7:06:39, 61.39s/it]
# [2025-11-07 22:58:16,162 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 146/562  |  Train Loss: 1.1048  |  Train Acc (sup/sub): 0.9546/0.7035  |  Val Loss: 1.2497  |  Val Acc (sup/sub): 0.9555/0.6534
#  17%|█▋        | 84/500 [1:25:24<7:04:53, 61.28s/it]
# [2025-11-07 22:59:16,673 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 22:59:16,689 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) - early-stop counter reset to 0.
# [2025-11-07 22:59:16,689 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 147/562  |  Train Loss: 1.0908  |  Train Acc (sup/sub): 0.9537/0.7042  |  Val Loss: 1.2040  |  Val Acc (sup/sub): 0.9603/0.6582
#  17%|█▋        | 85/500 [1:26:25<7:02:18, 61.06s/it]
# [2025-11-07 23:00:17,488 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 148/562  |  Train Loss: 1.0709  |  Train Acc (sup/sub): 0.9567/0.7090  |  Val Loss: 1.2418  |  Val Acc (sup/sub): 0.9618/0.6471
#  17%|█▋        | 86/500 [1:27:26<7:00:45, 60.98s/it]
# [2025-11-07 23:01:18,107 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 149/562  |  Train Loss: 1.0718  |  Train Acc (sup/sub): 0.9549/0.7077  |  Val Loss: 1.2552  |  Val Acc (sup/sub): 0.9603/0.6582
#  17%|█▋        | 87/500 [1:28:26<6:58:59, 60.87s/it]
# [2025-11-07 23:02:18,627 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 23:02:18,638 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) - early-stop counter reset to 0.
# [2025-11-07 23:02:18,639 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 150/562  |  Train Loss: 1.0913  |  Train Acc (sup/sub): 0.9548/0.7083  |  Val Loss: 1.1843  |  Val Acc (sup/sub): 0.9650/0.6693
#  18%|█▊        | 88/500 [1:29:27<6:57:16, 60.77s/it]
# [2025-11-07 23:03:18,959 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 151/562  |  Train Loss: 1.0821  |  Train Acc (sup/sub): 0.9546/0.7028  |  Val Loss: 1.2143  |  Val Acc (sup/sub): 0.9618/0.6423
#  18%|█▊        | 89/500 [1:30:27<6:55:20, 60.63s/it]
# [2025-11-07 23:04:19,219 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 152/562  |  Train Loss: 1.0696  |  Train Acc (sup/sub): 0.9548/0.7104  |  Val Loss: 1.2103  |  Val Acc (sup/sub): 0.9618/0.6677
#  18%|█▊        | 90/500 [1:31:27<6:53:34, 60.52s/it]
# [2025-11-07 23:05:19,911 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 153/562  |  Train Loss: 1.0635  |  Train Acc (sup/sub): 0.9539/0.7111  |  Val Loss: 1.2425  |  Val Acc (sup/sub): 0.9491/0.6502
#  18%|█▊        | 91/500 [1:32:28<6:52:54, 60.57s/it]
# [2025-11-07 23:06:20,352 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 154/562  |  Train Loss: 1.0442  |  Train Acc (sup/sub): 0.9579/0.7150  |  Val Loss: 1.2312  |  Val Acc (sup/sub): 0.9618/0.6661
#  18%|█▊        | 92/500 [1:33:29<6:51:37, 60.53s/it]
# [2025-11-07 23:07:20,568 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch
| INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 272/562  |  Train Loss: 0.7663  |  Train Acc (sup/sub): 0.9666/0.7864  |  Val Loss: 1.0877  |  Val Acc (sup/sub): 0.9618/0.6789
#  42%|████▏     | 210/500 [4:25:32<6:05:00, 75.52s/it]
# [2025-11-08 01:59:25,987 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 273/562  |  Train Loss: 0.7484  |  Train Acc (sup/sub): 0.9655/0.7908  |  Val Loss: 1.0153  |  Val Acc (sup/sub): 0.9587/0.7011
#  42%|████▏     | 211/500 [4:26:34<5:45:01, 71.63s/it]
# [2025-11-08 02:00:27,225 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 274/562  |  Train Loss: 0.7553  |  Train Acc (sup/sub): 0.9689/0.7902  |  Val Loss: 1.0634  |  Val Acc (sup/sub): 0.9603/0.7027
#  42%|████▏     | 212/500 [4:27:35<5:28:51, 68.51s/it]
# [2025-11-08 02:01:28,125 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 275/562  |  Train Loss: 0.7496  |  Train Acc (sup/sub): 0.9657/0.7955  |  Val Loss: 1.0135  |  Val Acc (sup/sub): 0.9650/0.7122
#  43%|████▎     | 213/500 [4:28:36<5:16:47, 66.23s/it]
# [2025-11-08 02:02:29,388 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 276/562  |  Train Loss: 0.7541  |  Train Acc (sup/sub): 0.9659/0.7911  |  Val Loss: 1.0354  |  Val Acc (sup/sub): 0.9618/0.6995
#  43%|████▎     | 214/500 [4:29:38<5:08:35, 64.74s/it]
# [2025-11-08 02:03:30,822 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 277/562  |  Train Loss: 0.7574  |  Train Acc (sup/sub): 0.9682/0.7910  |  Val Loss: 1.0315  |  Val Acc (sup/sub): 0.9730/0.7027
#  43%|████▎     | 215/500 [4:30:39<5:02:48, 63.75s/it]
# [2025-11-08 02:04:32,511 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 278/562  |  Train Loss: 0.7592  |  Train Acc (sup/sub): 0.9654/0.7906  |  Val Loss: 1.0550  |  Val Acc (sup/sub): 0.9618/0.6995
#  43%|████▎     | 216/500 [4:31:41<4:58:48, 63.13s/it]
# [2025-11-08 02:05:34,446 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-08 02:05:34,459 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (loss) - early-stop counter reset to 0.
# [2025-11-08 02:05:34,460 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 279/562  |  Train Loss: 0.7475  |  Train Acc (sup/sub): 0.9694/0.7922  |  Val Loss: 0.9637  |  Val Acc (sup/sub): 0.9714/0.7218
#  43%|████▎     | 217/500 [4:32:43<4:56:05, 62.78s/it]
# [2025-11-08 02:06:35,851 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-08 02:06:35,864 | INFO | CNN_3_128_Test_Aksel_v000 ] Improved (acc_sup) - early-stop counter reset to 0.
# [2025-11-08 02:06:35,864 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 280/562  |  Train Loss: 0.7363  |  Train Acc (sup/sub): 0.9657/0.7968  |  Val Loss: 1.0010  |  Val Acc (sup/sub): 0.9809/0.7154
#  44%|████▎     | 218/500 [4:33:44<4:53:06, 62.36s/it]
# [2025-11-08 02:07:37,086 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 281/562  |  Train Loss: 0.7304  |  Train Acc (sup/sub): 0.9666/0.7973  |  Val Loss: 1.0076  |  Val Acc (sup/sub): 0.9714/0.7075
#  44%|████▍     | 219/500 [4:34:45<4:50:28, 62.02s/it]
# [2025-11-08 02:08:38,248 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch
| INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 293/562  |  Train Loss: 0.7210  |  Train Acc (sup/sub): 0.9693/0.8023  |  Val Loss: 0.9978  |  Val Acc (sup/sub): 0.9634/0.7059
#  46%|████▌     | 231/500 [4:47:13<4:39:44, 62.40s/it]
# [2025-11-08 02:21:06,375 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 294/562  |  Train Loss: 0.7162  |  Train Acc (sup/sub): 0.9673/0.7968  |  Val Loss: 0.9917  |  Val Acc (sup/sub): 0.9682/0.7218
#  46%|████▋     | 232/500 [4:48:15<4:37:37, 62.15s/it]
# [2025-11-08 02:22:07,494 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 295/562  |  Train Loss: 0.7318  |  Train Acc (sup/sub): 0.9641/0.8005  |  Val Loss: 1.0076  |  Val Acc (sup/sub): 0.9634/0.7011
#  47%|████▋     | 233/500 [4:49:16<4:35:12, 61.84s/it]
# [2025-11-08 02:23:09,105 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 296/562  |  Train Loss: 0.7218  |  Train Acc (sup/sub): 0.9662/0.8042  |  Val Loss: 1.0137  |  Val Acc (sup/sub): 0.9618/0.6916
#  47%|████▋     | 234/500 [4:50:17<4:33:51, 61.77s/it]
# [2025-11-08 02:24:12,296 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 297/562  |  Train Loss: 0.7183  |  Train Acc (sup/sub): 0.9696/0.7971  |  Val Loss: 1.0180  |  Val Acc (sup/sub): 0.9682/0.7011
#  47%|████▋     | 235/500 [4:51:20<4:34:42, 62.20s/it]
# [2025-11-08 02:25:14,035 | INFO | CNN_3_128_Test_Aksel_v000 ] Epoch 298/562  |  Train Loss: 0.7299  |  Train Acc (sup/sub): 0.9685/0.7987  |  Val Loss: 1.0387  |  Val Acc (sup/sub): 0.9587/0.6852
#  47%|████▋     | 236/500 [4:52:44<5:27:28, 74.43s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.train_model(train_loader, val_loader, epochs=500)
#
# File ~/coding/Columbia/NNDL-Project/nndl_model/base_model.py:226, in BaseModel.train_model(self, train_loader, val_loader, epochs)
#     223 running_corrects_sub = 0
#     224 total = 0
# --> 226 for inputs, labels in train_loader:
#     227     inputs: torch.Tensor = inputs.to(device)
#     228     labels: torch.Tensor | TorchDict
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/torch/utils/data/dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1479, in _MultiProcessingDataLoaderIter._next_data(self)
#    1476 else:
#    1477     # no valid `self._rcvd_idx` is found (i.e., didn't break)
#    1478     if not self._persistent_workers:
# -> 1479         self._shutdown_workers()
#    1480     raise StopIteration
#    1482 # Now `self._rcvd_idx` is the batch index we want to fetch
#    1483
#    1484 # Check if the next sample has already been generated
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1627, in _MultiProcessingDataLoaderIter._shutdown_workers(self)
#    1622         self._mark_worker_as_unavailable(worker_id, shutdown=True)
#    1623 for w in self._workers:
#    1624     # We should be able to join here, but in case anything went
#    1625     # wrong, we set a timeout and if the workers fail to join,
#    1626     # they are killed in the `finally` block.
# -> 1627     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#    1628 for q in self._index_queues:
#    1629     q.cancel_join_thread()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/multiprocessing/popen_fork.py:40, in Popen.wait(self, timeout)
#      38 if timeout is not None:
#      39     from multiprocessing.connection import wait
# ---> 40     if not wait([self.sentinel], timeout):
#      41         return None
#      42 # This shouldn't block if wait() returned successfully.
#
# File ~/micromamba/envs/kret_312/lib/python3.12/multiprocessing/connection.py:1136, in wait(object_list, timeout)
#    1133     deadline = time.monotonic() + timeout
#    1135 while True:
# -> 1136     ready = selector.select(timeout)
#    1137     if ready:
#    1138         return [key.fileobj for (key, events) in ready]
#
# File ~/micromamba/envs/kret_312/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x17f2d47d0>> (for post_run_cell), with arguments args (<ExecutionResult object at 30e4fb080, execution_count=7 error_before_exec=None error_in_exec= info=<ExecutionInfo object at 30e4fb110, raw_cell="model.train_model(train_loader, val_loader, epochs.." transformed_cell="model.train_model(train_loader, val_loader, epochs.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/Akseldkw/coding/Columbia/NNDL-Project/notebooks/cnn_3_128_test_aksel.ipynb#X61sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:595, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     592     return
#     594 self._logger.info("resuming backend")
# --> 595 self.backend.interface.publish_resume()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface.py:818, in InterfaceBase.publish_resume(self)
#     816 def publish_resume(self) -> None:
#     817     resume = pb.ResumeRequest()
# --> 818     self._publish_resume(resume)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface_shared.py:296, in InterfaceShared._publish_resume(self, resume)
#     294 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     295     rec = self._make_request(resume=resume)
# --> 296     self._publish(rec)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface_sock.py:43, in InterfaceSock._publish(self, record, local)
#      41 request = spb.ServerRequest()
#      42 request.record_publish.CopyFrom(record)
# ---> 43 self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File ~/micromamba/envs/kret_312/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/asyncio/streams.py:392, in StreamWriter.drain(self)
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
# --> 392 await self._protocol._drain_helper()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/asyncio/streams.py:166, in FlowControlMixin._drain_helper(self)
#     164 async def _drain_helper(self):
#     165     if self._connection_lost:
# --> 166         raise ConnectionResetError('Connection lost')
#     167     if not self._paused:
#     168         return
#
# ConnectionResetError: Connection lost

# %%
model.summary()
# Out:
# Model: name='CNN_3_128_Test_Aksel_v000'
#
# CNN_3_128_Test_Aksel(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): AdaptiveAvgPool2d(output_size=1)
#     (5): Flatten(start_dim=1, end_dim=-1)
#   )
#   (criterion): CrossEntropyLoss()
#   (head_super): Linear(in_features=64, out_features=4, bias=True)
#   (head_sub): Linear(in_features=64, out_features=88, bias=True)
# )
#
# {'hparams': {'alpha': 1,
#              'beta': 1,
#              'gamma': 0.1,
#              'improvement_tol': 0.0001,
#              'lr': 0.001,
#              'patience': 10},
#  'state': {'best_acc_sub': 0.5135135135135135,
#            'best_acc_sup': 0.9475357710651828,
#            'best_loss': 1.83054162417383,
#            'epochs_trained': 51}}

# %%
model.save_weights()
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x1683567b0>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 30d4ad2b0, raw_cell="model.save_weights()" transformed_cell="model.save_weights()
# " store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/Akseldkw/coding/Columbia/NNDL-Project/notebooks/cnn_3_128_test_aksel.ipynb#X63sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:584, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     582 if self.backend.interface is not None:
#     583     self._logger.info("pausing backend")
# --> 584     self.backend.interface.publish_pause()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface.py:810, in InterfaceBase.publish_pause(self)
#     808 def publish_pause(self) -> None:
#     809     pause = pb.PauseRequest()
# --> 810     self._publish_pause(pause)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface_shared.py:292, in InterfaceShared._publish_pause(self, pause)
#     290 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     291     rec = self._make_request(pause=pause)
# --> 292     self._publish(rec)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface_sock.py:43, in InterfaceSock._publish(self, record, local)
#      41 request = spb.ServerRequest()
#      42 request.record_publish.CopyFrom(record)
# ---> 43 self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File ~/micromamba/envs/kret_312/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/asyncio/selector_events.py:1075, in _SelectorSocketTransport.write(self, data)
#    1072 if not self._buffer:
#    1073     # Optimization: try to send now.
#    1074     try:
# -> 1075         n = self._sock.send(data)
#    1076     except (BlockingIOError, InterruptedError):
#    1077         pass
#
# BrokenPipeError: [Errno 32] Broken pipe
# [2025-11-07 21:32:30,390 | INFO | CNN_3_128_Test_Aksel_v000 ] Saving model weights to /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000, view model summary at /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000/model.txt
# [2025-11-07 21:32:30,396 | WARNING | asyncio ] socket.send() raised exception.
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x1683567b0>> (for post_run_cell), with arguments args (<ExecutionResult object at 30d4ad4c0, execution_count=9 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 30d4ad2b0, raw_cell="model.save_weights()" transformed_cell="model.save_weights()
# " store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/Akseldkw/coding/Columbia/NNDL-Project/notebooks/cnn_3_128_test_aksel.ipynb#X63sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:595, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     592     return
#     594 self._logger.info("resuming backend")
# --> 595 self.backend.interface.publish_resume()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface.py:818, in InterfaceBase.publish_resume(self)
#     816 def publish_resume(self) -> None:
#     817     resume = pb.ResumeRequest()
# --> 818     self._publish_resume(resume)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface_shared.py:296, in InterfaceShared._publish_resume(self, resume)
#     294 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     295     rec = self._make_request(resume=resume)
# --> 296     self._publish(rec)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface_sock.py:43, in InterfaceSock._publish(self, record, local)
#      41 request = spb.ServerRequest()
#      42 request.record_publish.CopyFrom(record)
# ---> 43 self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File ~/micromamba/envs/kret_312/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/IPython/core/events.py:82, in EventManager.trigger(self, event, *args, **kwargs)
#      80 for func in self.callbacks[event][:]:
#      81     try:
# ---> 82         func(*args, **kwargs)
#      83     except (Exception, KeyboardInterrupt):
#      84         if self.print_on_error:
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:584, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     582 if self.backend.interface is not None:
#     583     self._logger.info("pausing backend")
# --> 584     self.backend.interface.publish_pause()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface.py:810, in InterfaceBase.publish_pause(self)
#     808 def publish_pause(self) -> None:
#     809     pause = pb.PauseRequest()
# --> 810     self._publish_pause(pause)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface_shared.py:292, in InterfaceShared._publish_pause(self, pause)
#     290 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     291     rec = self._make_request(pause=pause)
# --> 292     self._publish(rec)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/interface/interface_sock.py:43, in InterfaceSock._publish(self, record, local)
#      41 request = spb.ServerRequest()
#      42 request.record_publish.CopyFrom(record)
# ---> 43 self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File ~/micromamba/envs/kret_312/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/micromamba/envs/kret_312/lib/python3.12/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/micromamba/envs/kret_312/lib/python3.12/asyncio/selector_events.py:1075, in _SelectorSocketTransport.write(self, data)
#    1072 if not self._buffer:
#    1073     # Optimization: try to send now.
#    1074     try:
# -> 1075         n = self._sock.send(data)
#    1076     except (BlockingIOError, InterruptedError):
#    1077         pass
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
# raise ValueError("STOP")  # Remove this line to continue training

# %%
run.finish()
