# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nndl_model import *
import wandb

configure_logging()

# %%
# 1) Load data (uses DATA_DIR from your constants)
train_loader, val_loader, test_loader, M = make_dataloaders()

# %%
model = CNN_3_128_Test_Aksel(M=M)
# Out:
# [2025-11-08 02:43:50,786 | INFO | CNN_3_128_Test_Aksel_v000 ] Loaded model weights and state from /Users/Akseldkw/coding/Columbia/NNDL-Project/model_weights/CNN_3_128_Test_Aksel_v000.
# [2025-11-08 02:43:50,787 | INFO | CNN_3_128_Test_Aksel_v000 ] Full State:
# {'hparams': {'alpha': 1,
#              'beta': 1,
#              'gamma': 0.1,
#              'improvement_tol': 0.0001,
#              'lr': 0.001,
#              'patience': 60},
#  'state': {'best_acc_sub': 0.7281,
#            'best_acc_sup': 0.9809,
#            'best_loss': 0.939,
#            'epochs_trained': 279}}

# %%
run = start_wandb_run(model)
# Out:
# wandb: Currently logged in as: akseldkw (akseldkw07) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/Users/Akseldkw/coding/Columbia/COMS4776-Data/wandb/wandb/run-20251108_024352-2hkvter8</code>
# Syncing run <strong><a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/2hkvter8' target="_blank">CNN_3_128_Test_Aksel_v000__20251108-024350</a></strong> to <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition' target="_blank">https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition</a>
#  View run at <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/2hkvter8' target="_blank">https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/2hkvter8</a>

# %%
model.train_model(train_loader, val_loader, epochs=480)
# Out:
# [2025-11-08 09:15:36,160 | WARNING | CNN_3_128_Test_Aksel_v000 ] Early stopping activated: no improvement for 60 consecutive epochs.

# %%
model.summary()
# Out:
# Model: name='CNN_3_128_Test_Aksel_v000'
#
# CNN_3_128_Test_Aksel(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): AdaptiveAvgPool2d(output_size=1)
#     (5): Flatten(start_dim=1, end_dim=-1)
#   )
#   (criterion): CrossEntropyLoss()
#   (head_super): Linear(in_features=64, out_features=4, bias=True)
#   (head_sub): Linear(in_features=64, out_features=88, bias=True)
# )
#
# {'hparams': {'alpha': 1,
#              'beta': 1,
#              'gamma': 0.1,
#              'improvement_tol': 0.0001,
#              'lr': 0.001,
#              'patience': 60},
#  'state': {'best_acc_sub': 0.7695,
#            'best_acc_sup': 0.9825,
#            'best_loss': 0.815,
#            'epochs_trained': 576}}

# %%
# model.save_weights()

# %%
# raise ValueError("STOP")  # Remove this line to continue training

# %%
run.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train Accuracy (sub)</td><td>▂▁▁▁▃▄▃▃▃▄▅▅▅▅▅▅▆▅▆▅▆▆▅▆▅▆▆▆▇▇▇▆▇▇▇█▇▇▇█</td></tr><tr><td>Train Accuracy (super)</td><td>▂▄▄▃▁▃▄▅▃▅▄▅▅▆▅▅▆▆▅▆▆▅▆▇▇▆█▅▇▆▇▅█▇▇▇▆███</td></tr><tr><td>Train Loss</td><td>█████▇▇▇▇▇▆▆▆▆▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▂▂▁▁▁▁▁▁</td></tr><tr><td>Validation Accuracy (sub)</td><td>▂▁▄▃▁▃▂▃▂▄▃▄▃▄▃▅▅▅▃▄▅▅▆▆▄▅▅▆▆▆▆▆▅█▆▅▆▅▆▇</td></tr><tr><td>Validation Accuracy (super)</td><td>▇▂▆▃▃▁▅▆▄▃▃▂▄▂▄▇▆▃▂▁▃▆▃▇▂▃▂█▅▄▆▅▃▅▄▄▇▂▃▇</td></tr><tr><td>Validation Loss</td><td>█▇█▇▆▆▅▅▅▄▄▆▆▅▄▅▄▄▄▃▄▄▄▅▂▃▂▃▂▂▃▂▁▁▃▁▃▃▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train Accuracy (sub)</td><td>0.871</td></tr><tr><td>Train Accuracy (super)</td><td>0.97773</td></tr><tr><td>Train Loss</td><td>0.46077</td></tr><tr><td>Validation Accuracy (sub)</td><td>0.75358</td></tr><tr><td>Validation Accuracy (super)</td><td>0.97933</td></tr><tr><td>Validation Loss</td><td>0.85538</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">CNN_3_128_Test_Aksel_v000__20251108-024350</strong> at: <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/2hkvter8' target="_blank">https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition/runs/2hkvter8</a><br> View project at: <a href='https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition' target="_blank">https://wandb.ai/nndl-project-F25/Multihead-Classification-Competition</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/Users/Akseldkw/coding/Columbia/COMS4776-Data/wandb/wandb/run-20251108_024352-2hkvter8/logs</code>
